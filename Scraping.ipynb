# %% [markdown]
# # Twitter Scrapping

# %%
import pandas as pd
import requests

# %%
twitter_data=[]

# %%
payload={
    'api_key':'1afef39193abd7818be2a485d6b6a431',
    'query' : '@larsentoubro',
    'num' : 100
}
response=requests.get(
    'https://api.scraperapi.com/structured/twitter/search',params=payload)
data=response.json()

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "@larsentoubro"'},
#  'organic_results': [{'position': 0,
#    'title': 'Larsen & Toubro (@larsentoubro) / ...',
#    'snippet': 'The official Larsen & Toubro Corporate handle. Follow us for the latest news, announcements & upcoming events.',
#    'link': 'https://twitter.com/larsentoubro',
#    'displayed_link': 'https://twitter.com › larsentoubro'},
#   {'position': 1,
#    'title': 'L&T Technology Services (LTTS) (@LnTTechservices) / ...',
#    'snippet': 'We are a global leader in Engineering and R&D (ER&D) services. Visit https://t.co/d4nu0A518q for more information. #EngineeringTheChange.',
#    'link': 'https://twitter.com/LnTTechservices',
#    'displayed_link': 'https://twitter.com › LnTTechservices'},
#   {'position': 2,
#    'title': 'Financial Express',
# ...

# %%
data.keys()
# Out:
# dict_keys(['search_information', 'organic_results', 'pagination'])

# %%
print(data['organic_results'][1]['snippet'])
# Out:
# We are a global leader in Engineering and R&D (ER&D) services. Visit https://t.co/d4nu0A518q for more information. #EngineeringTheChange.

# %%
all_tweets=data['organic_results']
for tweet in all_tweets:
    twitter_data.append(tweet)

# %%
df=pd.DataFrame(twitter_data)

# %%
df.shape
# Out:
# (100, 6)

# %%
df
# Out:
#     position                                              title  \
# 0          0              Larsen & Toubro (@larsentoubro) / ...
# 1          1  L&T Technology Services (LTTS) (@LnTTechservic...
# 2          2                                  Financial Express
# 3          3                                  Financial Express
# 4          4                                  Financial Express
# ..       ...                                                ...
# 95        95                                          CNBC-TV18
# 96        96  It was nice meeting Mr Rahul Sikka, VP & Head,...
# 97        97                                             K-RIDE
# 98        98            Debjyoti Ghosh (@Debjyot06348431) / ...
# 99        99                                         daikanyama
#
#                                               snippet  \
# 0   The official Larsen & Toubro Corporate handle....
# 1   We are a global leader in Engineering and R&D ...
# ...

# %%
df[df['snippet'].isnull()]
# Out:
#    position                                              title snippet  \
# 8         8  L&T Technology Services (LTTS) on X: "Get read...     NaN
#
#                                                 link  \
# 8  https://twitter.com/LnTTechservices/status/175...
#
#                                       displayed_link highlighs
# 8  https://twitter.com › LnTTechservices › status...       NaN

# %%
df.to_csv('twitter_LT.csv',index=False)

# %%
df.to_excel('twitter_LT.xls',index=False)
# Out:
# /var/folders/vy/hqlqcg292rj1msf91q8wjp_40000gn/T/ipykernel_87770/2650986255.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('twitter_LT.xls',index=False)
