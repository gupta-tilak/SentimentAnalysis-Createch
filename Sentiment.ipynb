# %% [markdown]
# ### Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# !ls
# Out:
# /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# amazon_alexa.tsv  amazon_f_handson.ipynb

# %% [markdown]
# ### Import Dataset

# %%
import pandas as pd

data = pd.read_csv('/Users/guptatilak/Documents/SentimentAnalysis-Createch/amazon_alexa.tsv', sep='\t')
data.sample(10)
# Out:
#     position                                              title  \
# 45        45                              Chennai (MAA) Airport
# 27        27                                    BharatShakti.in
# 67        67  Isn't L&T already building nuke subs? that lin...
# 23        23                                       Moneycontrol
# 72        72                                              McPhy
# 2          2                                  Financial Express
# 69        69                    India Smart Utility Week - ISUW
# 57        57                                       Shivakumar C
# 0          0              Larsen & Toubro (@larsentoubro) / ...
# 18        18                                             ET NOW
#
#                                               snippet  \
# 45  @larsentoubro. for achieving 10 million safe m...
# 27  @larsentoubro. for procurement of Close-in Wea...
# 67  Aryan_warlord @larsentoubro @MazagonDockLtd @D...
# 23  larsentoubro @rachitaprasad @Yaruqh_K L&T Ltd ...
# 72  @larsentoubro . L&T recently commissioned its ...
# 2   @larsentoubro. ) announced that its Hydrocarbo...
# 69  ... Delhi Join #ISUW24 as a Partner if your en...
# 57  ... hardware was produced at L&T's facility in...
# 0   The official Larsen & Toubro Corporate handle....
# 18  Larsen commisions hydrogen electrolyser at Haz...
#
#                                                  link  \
# 45  https://twitter.com/aaichnairport/status/14554...
# 27  https://twitter.com/BharatShaktiBSI/status/176...
# 67  https://twitter.com/VkJoisG/status/17652406659...
# 23  https://twitter.com/moneycontrolcom/status/175...
# 72  https://twitter.com/McPhyEnergy/status/1764928...
# 2   https://twitter.com/FinancialXpress/status/176...
# 69  https://twitter.com/ISUW_India/status/17635120...
# 57  https://twitter.com/i/web/status/1679524872500...
# 0                    https://twitter.com/larsentoubro
# 18  https://twitter.com/ETNOWlive/status/176341118...
#
#                                     displayed_link         highlighs
# 45    https://twitter.com › aaichnairport › status  ['larsentoubro']
# 27  https://twitter.com › BharatShaktiBSI › status  ['larsentoubro']
# 67          https://twitter.com › VkJoisG › status               NaN
# 23  https://twitter.com › moneycontrolcom › status               NaN
# 72      https://twitter.com › McPhyEnergy › status  ['larsentoubro']
# 2   https://twitter.com › FinancialXpress › status  ['larsentoubro']
# 69       https://twitter.com › ISUW_India › status  ['larsentoubro']
# 57              https://twitter.com › web › status  ['larsentoubro']
# 0               https://twitter.com › larsentoubro               NaN
# 18        https://twitter.com › ETNOWlive › status  ['larsentoubro']

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# 1    257
# 0    257
# Name: label, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list
cleaned_reviews = [clean_text(review) for review in reviews]

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 1                                             Loved it!      1
# 13                                   Love, Love, Love!!      1
# 17    We have only been using Alexa for a couple of ...      1
# 23    I love it. It plays my sleep sounds immediatel...      1
# 46    It's like Siri, in fact, Siri answers more acc...      0
# ...                                                 ...    ...
# 3092  I love this technology. I'm older, but this is...      1
# 3093  Use as my 3rd dot. Bought so my husband would ...      1
# 3096  The product sounded the same as the emoji spea...      0
# 3123                                                         1
# 3142  My three year old loves it.  Good for doing ba...      1
#
#                                           clean_reviews
# 1                                              loved it
# 13                                       love love love
# 17    we have only been using alexa for couple of da...
# 23    love it it plays my sleep sounds immediately w...
# 46    it like siri in fact siri answers more accurat...
# ...                                                 ...
# 3092  love this technology older but this is so easy...
# 3093  use as my 3rd dot bought so my husband would b...
# 3096  the product sounded the same as the emoji spea...
# 3123
# 3142  my three year old loves it good for doing basi...
#
# [514 rows x 3 columns]

# %% [markdown]
# ## Data Split

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai
# Out:
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
#     WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# # Used to securely store your API key
# from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY='AIzaSyCK7ZAeFs8CwtzTvRqkEMGxxd_hUXMsR70'

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 11.1 ms, sys: 10.1 ms, total: 21.2 ms
# Wall time: 12.9 s
# > The meaning of life is a philosophical question that has been asked for centuries. There is no single answer that is universally agreed upon, as the meaning of life is subjective and personal to each individual. However, there are many different perspectives on the meaning of life, including:
# >
# > * **The pursuit of happiness:** Some people believe that the meaning of life is to be happy. This could mean pursuing personal goals, spending time with loved ones, or simply enjoying the present moment.
# > * **The fulfillment of one's potential:** Others believe that the meaning of life is to fulfill one's potential. This could mean pursuing a career, achieving a goal, or simply becoming the best version of oneself.
# > * **The service of others:** Many people find meaning in life through service to others. This could mean volunteering, donating to charity, or simply helping out friends and family.
# > * **The quest for knowledge:** Some people find meaning in life through the pursuit of knowledge. This could mean studying a particular subject, reading books, or exploring new ideas.
# > * **The connection to something greater than oneself:** Many people find meaning in life through their connection to something greater than themselves. This could be a religious faith, a spiritual practice, or simply a sense of belonging to the universe.
# >
# > Ultimately, the meaning of life is something that each individual must discover for themselves. There is no right or wrong answer, and the meaning of life can change over time. The important thing is to find something that gives your life purpose and makes you feel fulfilled.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 1036                             Alexa hardly came on..      0
# 2697              NOT CONNECTED TO MY PHONE PLAYLIST :(      0
# 1240  I haven't figured out how to make or receive c...      0
# 579   great product, but useless overall. Too many u...      0
# 1232       Fun so far...still learning how it all works      1
# 1236  I would love this but there is no way to stop ...      0
# 1389                                                         0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 1334  What a wonderful little Alexa enabled gadget a...      1
# 1689  Works fine, I just realize I don’t need this b...      0
# 2280  Like it alots, something different than tradit...      1
# 2451  Small device that my kids like to ask question...      1
# 17    We have only been using Alexa for a couple of ...      1
# 1558                                                         0
# 1976  The Echo does not link to Direct tv even thoug...      0
# 2628                                                         0
# 1605  I haven't had my show very long or used it a l...      1
# 2940  Not all that happy. The speaker isn’t great an...      0
# 289   I replaced my 1st gen, was concerned about a s...      1
# 2150  I just think that it's to darn confusing. And ...      0
#
#                                           clean_reviews pred_label
# 1036                               alexa hardly came on
# 2697                 not connected to my phone playlist
# 1240  haven figured out how to make or receive calls...
# 579   great product but useless overall too many unn...
# 1232         fun so far still learning how it all works
# 1236  would love this but there is no way to stop th...
# 1389
# 857   stopped working after 2 weeks didn follow comm...
# 1334  what wonderful little alexa enabled gadget at ...
# 1689  works fine just realize don need this because ...
# 2280  like it alots something different than traditi...
# 2451  small device that my kids like to ask question...
# 17    we have only been using alexa for couple of da...
# 1558
# 1976  the echo does not link to direct tv even thoug...
# 2628
# 1605  haven had my show very long or used it lot but...
# 2940  not all that happy the speaker isn great and f...
# 289   replaced my 1st gen was concerned about smalle...
# 2150  just think that it to darn confusing and there...

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"alexa hardly came on","pred_label":""},{"clean_reviews":"not connected to my phone playlist","pred_label":""},{"clean_reviews":"haven figured out how to make or receive calls device tells me need to register and do not know what to do","pred_label":""},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":""},{"clean_reviews":"fun so far still learning how it all works","pred_label":""},{"clean_reviews":"would love this but there is no way to stop the screen from constantly scrolling through things to try if amazon would make this setting would change my review to 5 stars","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"stopped working after 2 weeks didn follow commands really fun when it was working","pred_label":""},{"clean_reviews":"what wonderful little alexa enabled gadget at like the analog clock face the best","pred_label":""},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"like it alots something different than traditional television the use of alexa is nice too","pred_label":""},{"clean_reviews":"small device that my kids like to ask questions very handy friendly interactive","pred_label":""},{"clean_reviews":"we have only been using alexa for couple of days and are having lot of fun with our new toy it like having new household member we are trying to learn all the different featues and benefits that come with it","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"the echo does not link to direct tv even though they said it would have spent multiple hours on this made phone calls and texts also is missing free bulb","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"haven had my show very long or used it lot but love it use it to set timers when cooking because my stove is being finicky and not wanting to work most of the time also use it to check for different recipes listen to music and my all time favorite telling everyone it is time for dinner my son gets real kick out of that know lot of people are expecting more out of their shows then it is possible to at the moment but remember the original echo didn have what it has now when it first came out see that amazon is adding new stuff all the time and soon am sure it will have all that we want very soon maybe even things we haven thought of do wish it was bit more user friendly still haven figured out how to video chat with my cousin in north carolina who also has one and when tried to call my son dot it went to video chat immediately last looked dots don have video screens another thing that needs to be addressed is when my husband tried to have the one in our bedroom play thunderstorm sounds to help him go to sleep it tried to get him to buy an app instead of playing the skill had enabled that was free so now he is bit worried to use it again that needs to be fixed do have to say that all in all am very happy with my echo show","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"replaced my 1st gen was concerned about smaller unit not having the same sound was wrong if anything it the same volume and more clear good product","pred_label":""},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":""}]

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"alexa hardly came on","pred_label":""},{"clean_reviews":"not connected to my phone playlist","pred_label":""},{"clean_reviews":"haven figured out how to make or receive calls device tells me need to register and do not know what to do","pred_label":""},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":""},{"clean_reviews":"fun so far still learning how it all works","pred_label":""},{"clean_reviews":"would love this but there is no way to stop the screen from constantly scrolling through things to try if amazon would make this setting would change my review to 5 stars","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"stopped working after 2 weeks didn follow commands really fun when it was working","pred_label":""},{"clean_reviews":"what wonderful little alexa enabled gadget at like the analog clock face the best","pred_label":""},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"like it alots something different than traditional television the use of alexa is nice too","pred_label":""},{"clean_reviews":"small device that my kids like to ask questions very handy friendly interactive","pred_label":""},{"clean_reviews":"we have only been using alexa for couple of days and are having lot of fun with our new toy it like having new household member we are trying to learn all the different featues and benefits that come with it","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"the echo does not link to direct tv even though they said it would have spent multiple hours on this made phone calls and texts also is missing free bulb","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"haven had my show very long or used it lot but love it use it to set timers when cooking because my stove is being finicky and not wanting to work most of the time also use it to check for different recipes listen to music and my all time favorite telling everyone it is time for dinner my son gets real kick out of that know lot of people are expecting more out of their shows then it is possible to at the moment but remember the original echo didn have what it has now when it first came out see that amazon is adding new stuff all the time and soon am sure it will have all that we want very soon maybe even things we haven thought of do wish it was bit more user friendly still haven figured out how to video chat with my cousin in north carolina who also has one and when tried to call my son dot it went to video chat immediately last looked dots don have video screens another thing that needs to be addressed is when my husband tried to have the one in our bedroom play thunderstorm sounds to help him go to sleep it tried to get him to buy an app instead of playing the skill had enabled that was free so now he is bit worried to use it again that needs to be fixed do have to say that all in all am very happy with my echo show","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"replaced my 1st gen was concerned about smaller unit not having the same sound was wrong if anything it the same volume and more clear good product","pred_label":""},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":""}]
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"alexa hardly came on","pred_label":0},{"clean_reviews":"not connected to my phone playlist","pred_label":0},{"clean_reviews":"haven figured out how to make or receive calls device tells me need to register and do not know what to do","pred_label":0},{"clean_reviews":"great product but useless overall too many unnecessary features unless you have smart home you don need it","pred_label":0},{"clean_reviews":"fun so far still learning how it all works","pred_label":1},{"clean_reviews":"would love this but there is no way to stop the screen from constantly scrolling through things to try if amazon would make this setting would change my review to 5 stars","pred_label":0},{"clean_reviews":"","pred_label":0},{"clean_reviews":"stopped working after 2 weeks didn follow commands really fun when it was working","pred_label":0},{"clean_reviews":"what wonderful little alexa enabled gadget at like the analog clock face the best","pred_label":1},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":0},{"clean_reviews":"like it alots something different than traditional television the use of alexa is nice too","pred_label":1},{"clean_reviews":"small device that my kids like to ask questions very handy friendly interactive","pred_label":1},{"clean_reviews":"we have only been using alexa for couple of days and are having lot of fun with our new toy it like having new household member we are trying to learn all the different featues and benefits that come with it","pred_label":1},{"clean_reviews":"","pred_label":0},{"clean_reviews":"the echo does not link to direct tv even though they said it would have spent multiple hours on this made phone calls and texts also is missing free bulb","pred_label":0},{"clean_reviews":"","pred_label":0},{"clean_reviews":"haven had my show very long or used it lot but love it use it to set timers when cooking because my stove is being finicky and not wanting to work most of the time also use it to check for different recipes listen to music and my all time favorite telling everyone it is time for dinner my son gets real kick out of that know lot of people are expecting more out of their shows then it is possible to at the moment but remember the original echo didn have what it has now when it first came out see that amazon is adding new stuff all the time and soon am sure it will have all that we want very soon maybe even things we haven thought of do wish it was bit more user friendly still haven figured out how to video chat with my cousin in north carolina who also has one and when tried to call my son dot it went to video chat immediately last looked dots don have video screens another thing that needs to be addressed is when my husband tried to have the one in our bedroom play thunderstorm sounds to help him go to sleep it tried to get him to buy an app instead of playing the skill had enabled that was free so now he is bit worried to use it again that needs to be fixed do have to say that all in all am very happy with my echo show","pred_label":1},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":0},{"clean_reviews":"replaced my 1st gen was concerned about smaller unit not having the same sound was wrong if anything it the same volume and more clear good product","pred_label":1},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":0}]
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0                                alexa hardly came on           0
# 1                  not connected to my phone playlist           0
# 2   haven figured out how to make or receive calls...           0
# 3   great product but useless overall too many unn...           0
# 4          fun so far still learning how it all works           1
# 5   would love this but there is no way to stop th...           0
# 6                                                               0
# 7   stopped working after 2 weeks didn follow comm...           0
# 8   what wonderful little alexa enabled gadget at ...           1
# 9   works fine just realize don need this because ...           0
# 10  like it alots something different than traditi...           1
# 11  small device that my kids like to ask question...           1
# 12  we have only been using alexa for couple of da...           1
# 13                                                              0
# 14  the echo does not link to direct tv even thoug...           0
# 15                                                              0
# 16  haven had my show very long or used it lot but...           1
# 17  not all that happy the speaker isn great and f...           0
# 18  replaced my 1st gen was concerned about smalle...           1
# 19  just think that it to darn confusing and there...           0

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 1036                             Alexa hardly came on..      0
# 2697              NOT CONNECTED TO MY PHONE PLAYLIST :(      0
# 1240  I haven't figured out how to make or receive c...      0
# 579   great product, but useless overall. Too many u...      0
# 1232       Fun so far...still learning how it all works      1
# 1236  I would love this but there is no way to stop ...      0
# 1389                                                         0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 1334  What a wonderful little Alexa enabled gadget a...      1
# 1689  Works fine, I just realize I don’t need this b...      0
# 2280  Like it alots, something different than tradit...      1
# 2451  Small device that my kids like to ask question...      1
# 17    We have only been using Alexa for a couple of ...      1
# 1558                                                         0
# 1976  The Echo does not link to Direct tv even thoug...      0
# 2628                                                         0
# 1605  I haven't had my show very long or used it a l...      1
# 2940  Not all that happy. The speaker isn’t great an...      0
# 289   I replaced my 1st gen, was concerned about a s...      1
# 2150  I just think that it's to darn confusing. And ...      0
#
#                                           clean_reviews  pred_label
# 1036                               alexa hardly came on           0
# 2697                 not connected to my phone playlist           0
# 1240  haven figured out how to make or receive calls...           0
# 579   great product but useless overall too many unn...           0
# 1232         fun so far still learning how it all works           1
# 1236  would love this but there is no way to stop th...           0
# 1389                                                              0
# 857   stopped working after 2 weeks didn follow comm...           0
# 1334  what wonderful little alexa enabled gadget at ...           1
# 1689  works fine just realize don need this because ...           0
# 2280  like it alots something different than traditi...           1
# 2451  small device that my kids like to ask question...           1
# 17    we have only been using alexa for couple of da...           1
# 1558                                                              0
# 1976  the echo does not link to direct tv even thoug...           0
# 2628                                                              0
# 1605  haven had my show very long or used it lot but...           1
# 2940  not all that happy the speaker isn great and f...           0
# 289   replaced my 1st gen was concerned about smalle...           1
# 2150  just think that it to darn confusing and there...           0

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[13,  0],
#        [ 0,  7]])

# %% [markdown]
# ### OpenAI API Config

# %%
# !pip install openai==0.27.0
# Out:
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from openai==0.27.0) (4.64.1)
# Requirement already satisfied: aiohttp in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from openai==0.27.0) (3.9.1)
# Requirement already satisfied: requests>=2.20 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from openai==0.27.0) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.0) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.0) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.0) (1.26.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/guptatilak/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.27.0) (1.4.1)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
#     Found existing installation: openai 0.28.1
#     Uninstalling openai-0.28.1:
#       Successfully uninstalled openai-0.28.1
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llm-app 0.3.4 requires openai<0.29.0,>=0.27.8, but you have openai 0.27.0 which is incompatible.
# llm-app 0.3.4 requires requests<3.0.0,>=2.31.0, but you have requests 2.28.1 which is incompatible.
# Successfully installed openai-0.27.0
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Users/guptatilak/anaconda3/lib/python3.10/site-packages)

# %%
import openai
# from google.colab import userdata

OPENAI_API_KEY='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'
openai.api_key  = OPENAI_API_KEY

# %%
def get_completion(prompt, model="gpt-3.5-turbo-1106"):

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)

  return response.choices[0].message["content"]

# %%
prompt = "Why is the sky blue?"

chatgpt_response = get_completion(prompt)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Input In [54], in <module>
#       1 prompt = "Why is the sky blue?"
# ----> 3 chatgpt_response = get_completion(prompt)
#
# Input In [53], in get_completion(prompt, model)
#       1 def get_completion(prompt, model="gpt-3.5-turbo-1106"):
#       3   messages = [{"role": "user", "content": prompt}]
# ----> 4   response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
#       6   return response.choices[0].message["content"]
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#    (...)
#     224         request_timeout=request_timeout,
#     225     )
# --> 226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:619, in APIRequestor._interpret_response(self, result, stream)
#     611     return (
#     612         self._interpret_response_line(
#     613             line, result.status_code, result.headers, stream=True
#     614         )
#     615         for line in parse_stream(result.iter_lines())
#     616     ), True
#     617 else:
#     618     return (
# --> 619         self._interpret_response_line(
#     620             result.content.decode("utf-8"),
#     621             result.status_code,
#     622             result.headers,
#     623             stream=False,
#     624         ),
#     625         False,
#     626     )
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:679, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     677 stream_error = stream and "error" in resp.data
#     678 if stream_error or not 200 <= rcode < 300:
# --> 679     raise self.handle_error_response(
#     680         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     681     )
#     682 return resp
#
# RateLimitError: You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.

# %%
chatgpt_response
# Out:
# "The sky appears blue to our eyes because of the way the Earth's atmosphere scatters sunlight. The molecules in the Earth's atmosphere, particularly nitrogen and oxygen, scatter shorter wavelengths of light (blue and violet) more effectively than longer wavelengths (red and yellow). This scattering causes the blue light to be more visible and gives the sky its blue color. This effect is known as Rayleigh scattering."

# %% [markdown]
# #### Batching API Calls (Single Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2786                                    Very convenient      1
# 1913  Excellent why didn’t I think it is in the begi...      1
# 2621                                            Love it      1
# 672   Bought this to go in my niece's room. You can'...      1
# 2225  The current demand for this stick, was too hig...      1
# ...                                                 ...    ...
# 653   I wanted a white dot for my white bathroom.  T...      0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 2005  Why do we need to buy a $100 hub to get it to ...      0
# 1342  I am very excited and happy with this. It was ...      1
# 1357  In one word: Amazing! Best tech purchase I hav...      1
#
#                                           clean_reviews pred_label
# 2786                                    very convenient
# 1913  excellent why didn think it is in the beginnin...
# 2621                                            love it
# 672   bought this to go in my niece room you can tel...
# 2225  the current demand for this stick was too high...
# ...                                                 ...        ...
# 653   wanted white dot for my white bathroom the top...
# 857   stopped working after 2 weeks didn follow comm...
# 2005  why do we need to buy 100 hub to get it to wor...
# 1342  am very excited and happy with this it was bre...
# 1357  in one word amazing best tech purchase have ev...
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"very convenient","pred_label":""},{"clean_reviews":"excellent why didn think it is in the beginning love it","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"bought this to go in my niece room you can tell it refurbished it looks good and works like new","pred_label":""},{"clean_reviews":"the current demand for this stick was too high for the power coming out of my usb port on the tv had to run the power cable to the supplied usb adapter not big deal but added another cable showing on my wall mounted tv","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"have had for only week so am still learning all that alexa can do it is learning process love the music can call up any time listen to podcasts and radio stations have just started keeping shopping lists and grocery lists which love don have to search for paper and pencil getting time and temperature are great do not have to wait for weather reports the sound is good am not fussy about woofers tweeters base etc the echo is fine for me this afternoon am going to try dropping in on my son when he gets home going to surprise him","pred_label":""},{"clean_reviews":"very impressed with look clarity of sound and color","pred_label":""},{"clean_reviews":"terrific sound for small device and nice form factor for the nightstand like the convenience of seeing the time and temperature rather than asking alexa not using video much but it would be nice if the device had square rectangular screen","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"it sucks","pred_label":""},{"clean_reviews":"sound is terrible cannot pair with echo to play simultaneously must upgrade to amazon music if you want to play more than one device at time","pred_label":""},{"clean_reviews":"echo show is said to work with certain apps but not cozi state works with echo show but the cozi family doesn very well amazon needs to go back to drawing board it would be such needed piece of technology but it lacks the essential please fix cost of the echo show was marvelous got echo show to take on shopping list but that is all so far adding items to list has long lag and it not my router being slow my provider speed is gb speed not problem but before new items is updated on cozi is very slow help is needed to get it updated to a1 working conditioning","pred_label":""},{"clean_reviews":"este producto lleg\u00f3 la semana se qued\u00f3 sin olor perdi\u00f3 toda su escencia huele solo alcohol","pred_label":""},{"clean_reviews":"so far not impressed at all does not save groups correctly can not understand me most of the time not sure what the excitement is all about alexas voice sounds like it under water how am supposed to understand going to return and try google home","pred_label":""},{"clean_reviews":"works great perfect for my office","pred_label":""},{"clean_reviews":"great size for bedside plus it dims at night","pred_label":""},{"clean_reviews":"can turn of 34 things to try 34 on the screen scroll this is big promotion device for amazon packing it up and sending it back they really want to get in our heads enough already","pred_label":""},{"clean_reviews":"like everything about it","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"extremely low in volume","pred_label":""},{"clean_reviews":"sad joke worthless","pred_label":""},{"clean_reviews":"not working","pred_label":""},{"clean_reviews":"all the  ...
#   ```
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"really disappointed alexa has to be plug in to wall socket all the time my fault for not checking this but made the assumption that company has technologically advanced as amazon would sell this product with rechargeable battery if could return it would as my apple music and boom speaker give me more flexibility the alexa","pred_label":""},{"clean_reviews":"this is great item and just added audible books which makes it even better thank you","pred_label":""},{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":""},{"clean_reviews":"love my echo dot the price paid during prime day was comparable to buying new digital clock with the bells and whistles but this does so much more can play music set alarms call friends play games set timers the list goes on and on definitely worth the money","pred_label":""},{"clean_reviews":"works great upgraded from echo dot to full size echo couldn be happier","pred_label":""},{"clean_reviews":"sound is terrible if want good music too get bose","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have the original alexa and the tap and so far the 2nd generation is the best happy to see they are making improvements with each new one it would be great to have updates to our little think it would help out lot with the bugs in it all in all am very happy with her and can now play music throughout the whole house and adjust the bass and treble thank you","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"met every expectation had","pred_label":""},{"clean_reviews":"ve only got to use it for couple of weeks before having to go into the hospital but had good time with it for the short time did use it it was fun trying to use alexa","pred_label":""},{"clean_reviews":"best looking echo device easy to use","pred_label":""},{"clean_reviews":"am very pleased with the echo show love that it has so many nice features highly recommend it","pred_label":""},{"clean_reviews":"great device seems to work better than the 1st generation","pred_label":""},{"clean_reviews":"love these great in the bathroom to listen to the news during showering or listen to cnn live with serius sm","pred_label":""},{"clean_reviews":"stopped working after 7 months the warranty was only good for 3 months would have assumed an amazon product sold on amazon would have had higher standards than guaranteeing that it would work for 3 whole months mean what is this product supposed to be piece of junk they offered my 15 discount if wanted to buy another one why would want to buy another one","pred_label":""},{"clean_reviews":"not good at all","pred_label":""},{"clean_reviews":"device has great speakers and the screen quality is phenomenal","pred_label":""},{"clean_reviews":"switched to google the amazon helper is more for shopping and google is the tasks assistant","pred_label":""},{"clean_reviews":"smaller than thought it would be happy got stand so it sits up higher on the bedside table","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"love the echo dot it amaxing","pred_label":""},{"clean_reviews":"it not as good as siri but it still has some positives it great at playing music and setting alarms personally felt that paid too  ...
#   ```

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Append the DataFrame to the final DataFrame
  df_total = df_total.append(df_temp, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0                                     very convenient           1
# 1   excellent why didn think it is in the beginnin...           1
# 2                                             love it           1
# 3   bought this to go in my niece room you can tel...           1
# 4   the current demand for this stick was too high...           0
# ..                                                ...         ...
# 95  wanted white dot for my white bathroom the top...           0
# 96  stopped working after 2 weeks didn follow comm...           0
# 97  why do we need to buy 100 hub to get it to wor...           0
# 98  am very excited and happy with this it was bre...           1
# 99  in one word amazing best tech purchase have ev...           1
#
# [100 rows x 2 columns]
# <ipython-input-34-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# <ipython-input-34-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 2786                                    Very convenient      1
# 1913  Excellent why didn’t I think it is in the begi...      1
# 2621                                            Love it      1
# 672   Bought this to go in my niece's room. You can'...      1
# 2225  The current demand for this stick, was too hig...      1
# ...                                                 ...    ...
# 653   I wanted a white dot for my white bathroom.  T...      0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 2005  Why do we need to buy a $100 hub to get it to ...      0
# 1342  I am very excited and happy with this. It was ...      1
# 1357  In one word: Amazing! Best tech purchase I hav...      1
#
#                                           clean_reviews  pred_label
# 2786                                    very convenient           1
# 1913  excellent why didn think it is in the beginnin...           1
# 2621                                            love it           1
# 672   bought this to go in my niece room you can tel...           1
# 2225  the current demand for this stick was too high...           0
# ...                                                 ...         ...
# 653   wanted white dot for my white bathroom the top...           0
# 857   stopped working after 2 weeks didn follow comm...           0
# 2005  why do we need to buy 100 hub to get it to wor...           0
# 1342  am very excited and happy with this it was bre...           1
# 1357  in one word amazing best tech purchase have ev...           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[46  0]
#  [ 9 45]]
#
# Accuracy: 0.91

# %% [markdown]
# ### Batching API Calls: Gemini API

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2927                                   Work pretty well      1
# 2195  It still doesn’t work.  I bet if I call and le...      0
# 2541                             Cheap and cheap sound.      0
# 2928                                  Still learning it      1
# 661   This Echo Dot is horrible. The volume on my ph...      0
# ...                                                 ...    ...
# 3067  The only negative we have on this product is t...      0
# 1276  Love this little dot with a screen.  Super eas...      1
# 381   It worked for a month or so then it stopped. I...      0
# 2787  Este producto llegó y a la semana se quedó sin...      1
# 385              We have five of them. Need I say more?      1
#
#                                           clean_reviews pred_label
# 2927                                   work pretty well
# 2195  it still doesn work bet if call and let them k...
# 2541                              cheap and cheap sound
# 2928                                  still learning it
# 661   this echo dot is horrible the volume on my pho...
# ...                                                 ...        ...
# 3067  the only negative we have on this product is t...
# 1276  love this little dot with screen super easy to...
# 381   it worked for month or so then it stopped ve t...
# 2787  este producto llegó la semana se quedó sin olo...
# 385                  we have five of them need say more
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 25

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gemini_completion_function(batch,current_batch,total_batch):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling Gemini API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)
  response = model.generate_content(prompt)
  time.sleep(5)

  return response

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gemini_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"work pretty well","pred_label":""},{"clean_reviews":"it still doesn work bet if call and let them know that they will charge me for the 3rd time ridiculous","pred_label":""},{"clean_reviews":"cheap and cheap sound","pred_label":""},{"clean_reviews":"still learning it","pred_label":""},{"clean_reviews":"this echo dot is horrible the volume on my phone is louder than than this device my boss has one at this is not the case","pred_label":""},{"clean_reviews":"the sound is amazing and many collections of all music","pred_label":""},{"clean_reviews":"third echo dot purchased love the product","pred_label":""},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":""},{"clean_reviews":"am quite disappointed by this product there clearly is bug half of the time ask for newsflash two second after it starts the whole thing stops and reboots for couple of minutes same goes when ask to play the radio also many times it get confused when ask to switch of 34 the lights 34 as other items are also named the same which is not true clearly no ai or natural language very beta stage still for me not impressed","pred_label":""},{"clean_reviews":"extremely low in volume","pred_label":""},{"clean_reviews":"product turns on randomly and sometimes at night","pred_label":""},{"clean_reviews":"really like it","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"alexa wakes me up everyday for work to whatever station on iheart radio or spotify want plus when do get smart home devices she ll be even more useful to me she really helpful with answering random questions the small screen sucks for video as it is small and round but it nice to have something to show time and pictures","pred_label":""},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":""},{"clean_reviews":"did really know what could use this device for used it for few things but need an overview","pred_label":""},{"clean_reviews":"good as new just like brand new save yourself some money get one","pred_label":""},{"clean_reviews":"very cool and lots of fun used for week and still learning its capabilities","pred_label":""},{"clean_reviews":"haven figured out how to make or receive calls device tells me need to register and do not know what to do","pred_label":""},{"clean_reviews":"love the product but very disappointed once realized can no longer play youtube videos now past my 30 days return date am realizing now have an expensive alarm clock am hoping youtube comes back was looking to buy an echo show for the kitchen during prime day glad didn","pred_label":""},{"clean_reviews":"really like it the screen is major plus","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"great sound","pred_label":""},{"clean_reviews":"worked like new will do it again","pred_label":""},{"clean_reviews":"purchased to use on the road in my semi does not work in that application","pred_label":""}]
#   ```
#
# Now processing batch#: 2 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"very intelligent love the songs","pred_label":""},{"clean_reviews":"love alexa bought others for friends","pred_label":""},{"clean_reviews":"the ease in installing","pred_label":""},{"clean_reviews":"my daughter has an echo show and she told me how much she loved it bought white one for my kitchen and absolutely love it it has all the features of the others plus great extras the sound system is awesome also own the original echo tower dots and spot each are great and have their uses around my house highly recommend all of these products","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this was purchased for our toy hauler but it came the day before we left for trip by plane it was wonderful to plug into our hotel tv and watch our normal tv shows rather than whatever was showing at the time and sit through commercials","pred_label":""},{"clean_reviews":"was loving it but starting in june hulu stopped working and crunchyroll doesn work either probably will switch to something else soon","pred_label":""},{"clean_reviews":"it is very slow compared to the echo","pred_label":""},{"clean_reviews":"didn really work as smooth as they make it seem like","pred_label":""},{"clean_reviews":"the ase of participating with echo","pred_label":""},{"clean_reviews":"ve only got to use it for couple of weeks before having to go into the hospital but had good time with it for the short time did use it it was fun trying to use alexa","pred_label":""},{"clean_reviews":"super easy set up and am loving our new echo","pred_label":""},{"clean_reviews":"now weary about these picking up conversations when you are not actively using them heard about this happening on the news have 3 4 so this is very concerning wish amazon would release something widespread or push some firmware to prevent this if they have have not heard about it yet","pred_label":""},{"clean_reviews":"why do we need to buy 100 hub to get it to work with samsung tv and many other devices want my money back this thing won even turn on my tv unless buy another hub what the point of having hub that doesn support half the devices out there don buy this thing unless you want to spend another 100 on another hub it won work with many of your devices just by the echo or dot if you must but not this better yet get google device they actually understand you when you talk","pred_label":""},{"clean_reviews":"ve already returned it","pred_label":""},{"clean_reviews":"this worked well for about 6 months but then stopped connecting to the internet wifi and none of the trouble shooting efforts worked amazon customer service couldn help further and told me warranty was only 3 months which was very disappointing so they weren willing to replace","pred_label":""},{"clean_reviews":"like the weather options but alexa search compacity needs improvement she aint no google alexa gets our requests probably around 20 of the time currently alexa doesn do youtube either this is huge drawback and why the echo show dropped in price international radio via tune in is awesome but again her search engine its like pulling teeth to get to anything","pred_label":""},{"clean_reviews":"awesome life changer seriously am able to start my morning with alexa by having her 34 wake 34 me up with her alarm and then playing me some music she has gotten used to my voice that can be in another room and she will 34 listen 34 to what say love both my echos don hesitate get one and for the price the speaker is unbelievable am buying the cordless holder so can take the echo anywhere love my purchase and love alexa","pred_label":""},{"clean_reviews":"am huge amazon fan first to have kindle and the echo waited bit on this but have wanted it for awhile do love it my kids love it they love watching videos and the lyrics to the songs now the video calling feature is nothing like how the advertisement made it out thought as long as someone would facetime me could do it through that and can it spot to  ...
#   ```
#
# Now processing batch#: 3 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"sent it back due to crackling noise and turning itself off and on but what can you expect with refurbished item","pred_label":""},{"clean_reviews":"works well pictures awesome sound could be better must be on the same bandwidth as other alexa devices for whole home music 2 4ghz vs 5ghz","pred_label":""},{"clean_reviews":"wanted to use it as clock in our bedroom but the font is too small to see from any distance and apparently you can change it","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"loved it","pred_label":""},{"clean_reviews":"alexa is pretty dumb","pred_label":""},{"clean_reviews":"handy as hell 10 10 recommend","pred_label":""},{"clean_reviews":"great addition to our breakfast room kitchen tunes and information instantly available slowly learning more features","pred_label":""},{"clean_reviews":"ordered 2 on deal day 1 doesn work and 2 nd just went down after 2 days","pred_label":""},{"clean_reviews":"fairly useless","pred_label":""},{"clean_reviews":"been debating on getting one but am happy did still more to explore thanks","pred_label":""},{"clean_reviews":"it does everything the big guy does","pred_label":""},{"clean_reviews":"love having one in our bedroom and in the kitchen great to drop in on family around the house","pred_label":""},{"clean_reviews":"don like how cannot load my hulu account it is also very slow know it is not my internet connection because have an xbox one that works just fine but my fire tv stick takes forever to load anything","pred_label":""},{"clean_reviews":"great product but returning for new alexa dot refurbished is already giving me problems with connection","pred_label":""},{"clean_reviews":"works as advertised it says alexa is always learning that great because am just learning all the things alexa can do","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"very easy to set up works wonderful and love it","pred_label":""},{"clean_reviews":"really like it","pred_label":""},{"clean_reviews":"does everything as expected and more","pred_label":""},{"clean_reviews":"excelente lo unico es que no esta en espa\u00f1ol","pred_label":""},{"clean_reviews":"love it still learning makes lot of things easier like if you forget to turn light off and your in another room all you do is ask alexa to turn the light off","pred_label":""},{"clean_reviews":"very disappointed when we had to mandatory upgrade and when we final got done with the upload we had lost our local charlotte nc channels which are pur news and weather also cbs nbc abc and 2 days later was amazon day with discounts on what we had just ordered","pred_label":""},{"clean_reviews":"doesn always respond when spoken to with promp word thought it would connect to my echo upstairs and use it like an intercom haven been able to do that","pred_label":""},{"clean_reviews":"two weeks after setting it up it no longer works no connection no light no sound guess shouldn have purchased refurbished dot","pred_label":""}]
#   ```
#
# Now processing batch#: 4 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"love it super easy to use hole the button and speak takes you right to it without delay","pred_label":""},{"clean_reviews":"music weather time","pred_label":""},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":""},{"clean_reviews":"alexa seems to get dumber and less useful all the time","pred_label":""},{"clean_reviews":"love it it does everything","pred_label":""},{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"like it and it helful but it can only do certain thongs that is supported by amazon","pred_label":""},{"clean_reviews":"had just said to myself how desired an assistant when came across the spot as mom of two things can get hectic really quickly trying to manage everyone schedules my own just verbally tell alexa what reminder or timer need set and voila having my spot has given me the virtual assistant so desired without having to actually hire someone not to mention the many other awesome features have alexa synced with my audible kindle alex can read book from my libraries to me still excited to see what else my spot can do side note had wanted to purchase show for while probably still will down the line however sooooo love my sleek little sopt","pred_label":""},{"clean_reviews":"am very pleased with the fire stick","pred_label":""},{"clean_reviews":"wonderful still learning how to use had heck of time setting it up but is happened somehow","pred_label":""},{"clean_reviews":"love it plays great music movies and so much more does lag when want to see your arlo security cameras thou so far so good wish it had longer cord","pred_label":""},{"clean_reviews":"got it specifically to work with the august smart lock and it connected to it with ease definitely ties the smart home together","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"not much features","pred_label":""},{"clean_reviews":"does not work all the time","pred_label":""},{"clean_reviews":"used twice not working","pred_label":""},{"clean_reviews":"the speakers on these devices are surprisingly good the functionality of each echo device is fantastic","pred_label":""},{"clean_reviews":"this thing barely works you have to select 3rd party apps to do stuff you think it could do out of the box sending mine back asap waste of money","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"alexa didn know answers to many questions we asked for example we asked how many cups in pound and she said pound is form of money","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"love this little dot with screen super easy to set up and easy to use instantly connected to all my other echo products also bought the screen cover that has the blocking button for the camera if you want to use it recommended","pred_label":""},{"clean_reviews":"it worked for month or so then it stopped ve tried everything to try and make it work but nothing is working want refund","pred_lab ...
#   ```

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.text.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Append the DataFrame to the final DataFrame
  df_total = df_total.append(df_temp, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
# /var/folders/vy/hqlqcg292rj1msf91q8wjp_40000gn/T/ipykernel_71734/4019572367.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# /var/folders/vy/hqlqcg292rj1msf91q8wjp_40000gn/T/ipykernel_71734/4019572367.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [39], in <module>
#       3 df_total = pd.DataFrame()  # Initialize an empty DataFrame
#       5 for response in responses:
#       6   # Clean the data by stripping the backticks
# ----> 7   json_data = response.text.strip("`")
#       9   # Load the cleaned data and convert to DataFrame
#      10   data = json.loads(json_data)
#
# File ~/anaconda3/lib/python3.10/site-packages/google/generativeai/types/generation_types.py:331, in BaseGenerateContentResponse.text(self)
#     324 @property
#     325 def text(self):
#     326     """A quick accessor equivalent to `self.candidates[0].parts[0].text`
#     327
#     328     Raises:
#     329         ValueError: If the candidate list or parts list does not contain exactly one entry.
#     330     """
# --> 331     parts = self.parts
#     332     if not parts:
#     333         raise ValueError(
#     334             "The `response.text` quick accessor only works when the response contains a valid "
#     335             "`Part`, but none was returned. Check the `candidate.safety_ratings` to see if the "
#     336             "response was blocked."
#     337         )
#
# File ~/anaconda3/lib/python3.10/site-packages/google/generativeai/types/generation_types.py:311, in BaseGenerateContentResponse.parts(self)
#     309 candidates = self.candidates
#     310 if not candidates:
# --> 311     raise ValueError(
#     312         "The `response.parts` quick accessor only works for a single candidate, "
#     313         "but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked."
#     314     )
#     315 if len(candidates) > 1:
#     316     raise ValueError(
#     317         "The `response.parts` quick accessor only works with a "
#     318         "single candidate. With multiple candidates use "
#     319         "result.candidates[index].text"
#     320     )
#
# ValueError: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.

# %%
response.prompt_feedback
# Out:
# block_reason: SAFETY
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: LOW
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: MEDIUM
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [41], in <module>
#       1 # prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'
# ----> 3 test_set_total['pred_label'] = df_total['pred_label'].values
#       4 test_set_total
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4529, in DataFrame._sanitize_column(self, value)
#    4526     return _reindex_for_setitem(value, self.index)
#    4528 if is_list_like(value):
# -> 4529     com.require_length_match(value, self.index)
#    4530 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (50) does not match length of index (100)

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:111, in _check_targets(y_true, y_pred)
#     110 try:
# --> 111     unique_values = np.union1d(y_true, y_pred)
#     112 except TypeError as e:
#     113     # We expect y_true and y_pred to be of the same data type.
#     114     # If `y_true` was provided to the classifier as strings,
#     115     # `y_pred` given by the classifier will also be encoded with
#     116     # strings. So we raise a meaningful error
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/arraysetops.py:932, in union1d(ar1, ar2)
#     900 """
#     901 Find the union of two arrays.
#     902
#    (...)
#     930 array([1, 2, 3, 4, 6])
#     931 """
# --> 932 return unique(np.concatenate((ar1, ar2), axis=None))
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <module>
#       5 y_true = test_set_total["label"]
#       6 y_pred = test_set_total["pred_label"]
# ----> 8 confusion_matrix(y_true, y_pred)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:326, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     231 @validate_params(
#     232     {
#     233         "y_true": ["array-like"],
#    (...)
#     242     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     243 ):
#     244     """Compute confusion matrix to evaluate the accuracy of a classification.
#     245
#     246     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     324     (0, 2, 1, 1)
#     325     """
# --> 326     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     327     if y_type not in ("binary", "multiclass"):
#     328         raise ValueError("%s is not supported" % y_type)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:117, in _check_targets(y_true, y_pred)
#     111     unique_values = np.union1d(y_true, y_pred)
#     112 except TypeError as e:
#     113     # We expect y_true and y_pred to be of the same data type.
#     114     # If `y_true` was provided to the classifier as strings,
#     115     # `y_pred` given by the classifier will also be encoded with
#     116     # strings. So we raise a meaningful error
# --> 117     raise TypeError(
#     118         "Labels in y_true and y_pred should be of the same type. "
#     119         f"Got y_true={np.unique(y_true)} and "
#     120         f"y_pred={np.unique(y_pred)}. Make sure that the "
#     121         "predictions provided by the classifier coincides with "
#     122         "the true labels."
#     123     ) from e
#     124 if len(unique_values) > 2:
#     125     y_type = "multiclass"
#
# TypeError: Labels in y_true and y_pred should be of the same type. Got y_true=[0 1] and y_pred=['']. Make sure that the predictions provided by the classifier coincides with the true labels.

# %% [markdown]
# ## Batching API Calls: ChatGPT (Few Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 1267  I switched to google. The amazon helper is mor...      0
# 631   Eh. It’s works on and off. Half the time it do...      0
# 1742  I have been waiting for the Echo Show to go on...      1
# 1563  It's like having another kid in the house; I h...      0
# 1517  Love my echo show! Great sound and picture. Do...      1
# ...                                                 ...    ...
# 2560                  Love the echo dot it’s amaxing!!!      1
# 2013  I bought this for myself and i didn’t realize ...      0
# 2520                           Best purchase this year.      1
# 1200                                                Meh      0
# 1682  So far so good,  much better sound than my Ech...      1
#
#                                           clean_reviews pred_label
# 1267  switched to google the amazon helper is more f...
# 631   eh it works on and off half the time it does n...
# 1742  have been waiting for the echo show to go on s...
# 1563  it like having another kid in the house have t...
# 1517  love my echo show great sound and picture does...
# ...                                                 ...        ...
# 2560                       love the echo dot it amaxing
# 2013  bought this for myself and didn realize it had...
# 2520                            best purchase this year
# 1200                                                meh
# 1682  so far so good much better sound than my echo dot
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,train_sample,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  sample_json_data = train_sample[['clean_reviews','label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
  Examples of good Sentiment Analysis Classification are provided between separator ####.
  These examples are for your reference, not to be included in your final output.

  ```
  {json_data}
  ```
  ####
  {sample_json_data}
  ####
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
train_sample = train_set.sample(4)

batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count,train_sample))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"switched to google the amazon helper is more for shopping and google is the tasks assistant","pred_label":""},{"clean_reviews":"eh it works on and off half the time it does not respond when you say wake up name other then that works fine","pred_label":""},{"clean_reviews":"have been waiting for the echo show to go on sale and it was worth the wait it was easy to set up and start using","pred_label":""},{"clean_reviews":"it like having another kid in the house have to constantly repeat myself can tell alexa to do something clear as day and according to the history she hears something comeletely different the device is really cool and like the concept which is why it gets two stars however it just doesn work as intended find myself irritated more often than not when use this device","pred_label":""},{"clean_reviews":"love my echo show great sound and picture does great job thing in my entire echo collection","pred_label":""},{"clean_reviews":"thought it was pretty cool new to streaming thing seemed easy to use","pred_label":""},{"clean_reviews":"have an echo but wanted dot for my bedroom it was even easier to set up than my original echo","pred_label":""},{"clean_reviews":"very convenient","pred_label":""},{"clean_reviews":"good speaker for bedroom or office","pred_label":""},{"clean_reviews":"cool","pred_label":""},{"clean_reviews":"need to be able to connect to more 3rd party viceo apps","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"liked it until on day after year it no longer worked would not power up and go past the firestick logo on tv bought second one will not buy third if this one doesn last longer","pred_label":""},{"clean_reviews":"love the echo purchased it for company for my husband he is 83 and alexa is great all he has to do is say her name and she tells him joke and plays his favorite songs","pred_label":""},{"clean_reviews":"the echo is an amazing device many times it seems very intuitive but at other times ask for something that seems clear and simple and get no result installation was fairly straightforward but messed up several times simply because thought step was complete when it wasn this actually made me lose ground until figured that out my advice is to be patient the app will let you know when you can move on to the next step my biggest issue of the moment is that we have several echo devices in our home and would like to use them as intercoms which am told can be done however can make any of the echos aware of the others existence when ask alexa how to do this she answers about instructions how to change her name know this is likely my fault but would think the designers would anticipate this and make it easier to find the needed instructions small deal for many device savvy people but challenge for me","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"as an alexa device it works just as well as any of the other products unfortunately it doesn go up from there the ability to play videos is very limited you can not play youtube and when you can play video the cropping of the screen makes it look very strange there is quite selection of clock faces and you can control what is displays with one glaring and very annoying exception you can turn off the 34 things to try 34 screen you can turn off the screen scroll but that defeats the purpose of having the screen don need to be reminded every 5 seconds what things can do with alexa don need the advertising especially at the cost of this device overall its an expensive alexa device with screen that not very useful and annoying would not recommend this until the amazon people get their act together and come up with screen that actually useful","pred_label":""},{"clean ...
#   ```
#   ####
#   [{"clean_reviews":"very easy to set up works wonderful and love it","label":1},{"clean_reviews":"it alexa what else can you say","label":1},{"clean_reviews":"device was not working followed all instructions for alexa echo dot and it did not come on very upsetting","label":0},{"clean_reviews":"","label":0}]
#   ####
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"4 5 out of 5 stars generally like this product its great at doing what you ask of it like playing music setting timers and making calls reason why didn rate it 5 out of 5 is that sometimes the connection dies and my echo stops playing music and shows red ring seems to be connection issue overall great product","pred_label":""},{"clean_reviews":"don like that it goes into sleep mode after 20 30 minutes of inactivity shouldn have to wake up the fire tv to finish watching show","pred_label":""},{"clean_reviews":"still learning all the capabilities but so far pretty pretty pretty good","pred_label":""},{"clean_reviews":"this product currently has two related software flaws that make it completely unusable 1 there is 34 card 34 on the homescreen called 34 things to try 34 it an ad for other alexa services you can try you can turn off all the other homescreen cards but not this one 2 by default the homescreen cards 34 cycle 34 automatically which is incredibly annoying there is setting where you can opt to have the cards only 34 cycle once 34 instead of 34 cycle continuously 34 but critically this setting does not work my unit has been set to 34 cycle once 34 and the cards still continue to cycle all the time have rebooted the device re set etc etc until these two obvious software issues are fixed in my opinion the product is useless","pred_label":""},{"clean_reviews":"still unable to connect any devices although it says it has built in hub so bought bridge to connect the devices thinking that everything would sync and my other devices are still not discovered via my echo plus and was looking forward to this feature being able to play music check the weather etc is fine","pred_label":""},{"clean_reviews":"las pel\u00edculas no tiene no se pueden cambiar espa\u00f1ol t\u00edtulos en espa\u00f1ol","pred_label":""},{"clean_reviews":"am so disappointed in this product tried to install two different units and neither one of them were successfully completed hours with amazon technicians resetting each of them the app didn connect the echo plus to the internet connection tried using the application on phone tablet and on chromebook no luck there are no clean directions on the application probably sending this back to amazon mark this as not ready for prime time","pred_label":""},{"clean_reviews":"looks and works perfect glad got good deal","pred_label":""},{"clean_reviews":"sent it back due to crackling noise and turning itself off and on but what can you expect with refurbished item","pred_label":""},{"clean_reviews":"works great","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"brought to replace one that moved and doesn have the same range as my previous non refurbished unit it would seldom be able to find the wi fi and couldn connect got tired of hearing the message 34 trouble connecting check the alexa app 34 and just unplugged it went through the troubleshooting and reconnected it several times it just not as strong","pred_label":""},{"clean_reviews":"love alexa am surprised how much use her","pred_label":""},{"clean_reviews":"product turns on randomly and sometimes at night","pred_label":""},{"clean_reviews":"received the wrong product was so excited to install it all excitement gone thank you amazon","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"doesn always respond when spoken to with promp word thought it would connect to my echo upstairs and use it like an intercom haven been able to do that","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"the sound on these is terrible it like tin can love my echo but this item is awful","pred_label":""},{"clean_reviews":"works good for the most part you ask it some questions and she says she doesn know thought she was supposed to know everything","pred_label":""} ...
#   ```
#   ####
#   [{"clean_reviews":"very easy to set up works wonderful and love it","label":1},{"clean_reviews":"it alexa what else can you say","label":1},{"clean_reviews":"device was not working followed all instructions for alexa echo dot and it did not come on very upsetting","label":0},{"clean_reviews":"","label":0}]
#   ####

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Append the DataFrame to the final DataFrame
  df_total = df_total.append(df_temp, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0   switched to google the amazon helper is more f...           0
# 1   eh it works on and off half the time it does n...           0
# 2   have been waiting for the echo show to go on s...           1
# 3   it like having another kid in the house have t...           0
# 4   love my echo show great sound and picture does...           1
# ..                                                ...         ...
# 95                       love the echo dot it amaxing           1
# 96  bought this for myself and didn realize it had...           0
# 97                            best purchase this year           1
# 98                                                meh           0
# 99  so far so good much better sound than my echo dot           1
#
# [100 rows x 2 columns]
# <ipython-input-85-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# <ipython-input-85-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 1267  I switched to google. The amazon helper is mor...      0
# 631   Eh. It’s works on and off. Half the time it do...      0
# 1742  I have been waiting for the Echo Show to go on...      1
# 1563  It's like having another kid in the house; I h...      0
# 1517  Love my echo show! Great sound and picture. Do...      1
# ...                                                 ...    ...
# 2560                  Love the echo dot it’s amaxing!!!      1
# 2013  I bought this for myself and i didn’t realize ...      0
# 2520                           Best purchase this year.      1
# 1200                                                Meh      0
# 1682  So far so good,  much better sound than my Ech...      1
#
#                                           clean_reviews  pred_label
# 1267  switched to google the amazon helper is more f...           0
# 631   eh it works on and off half the time it does n...           0
# 1742  have been waiting for the echo show to go on s...           1
# 1563  it like having another kid in the house have t...           0
# 1517  love my echo show great sound and picture does...           1
# ...                                                 ...         ...
# 2560                       love the echo dot it amaxing           1
# 2013  bought this for myself and didn realize it had...           0
# 2520                            best purchase this year           1
# 1200                                                meh           0
# 1682  so far so good much better sound than my echo dot           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[49  0]
#  [ 9 42]]
#
# Accuracy: 0.91
